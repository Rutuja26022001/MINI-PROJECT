# %% [markdown]
# #  Introduction :

# %% [markdown]
# ####  we  explored the covid 19 cases and death .  This data is downloaded from internate and try  to explored data set and do some curve fit
# first we import the libraries pandas,numpy,matplotlib,and scipy.
#
#
#
#
#
#
#
# we define the path of the object.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# there are two part of the these mini project
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1) Explore the data set
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2) Explore the best curve fit

# %% [markdown]
# ### plotting united_state_covid-19_cases_and_deathes_by_state_over_with best fit curves.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
csv = "United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv"
# url of the csv file

# %% [markdown]
# ###  creating data frame
# after define the path of the data we read the csv file by using {pd.read_csv("")} command.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# further we convert the data into data frame using the pandas.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# create an array of all the column names.

# %%
covid19 = pd.read_csv(csv)   # import the csv.file
df = pd.DataFrame(covid19)   #build up the pandas dataframe
print(df.columns)            #visualize the header
# Out:
# Index(['submission_date', 'state', 'tot_cases', 'conf_cases', 'prob_cases',
#        'new_case', 'pnew_case', 'tot_death', 'conf_death', 'prob_death',
#        'new_death', 'pnew_death', 'created_at', 'consent_cases',
#        'consent_deaths'],
#       dtype='object')

# %%
df.shape       ##The "shape" of an array is a tuple with the number of elements per axis (dimension).
# Out:
# (50361, 15)

# %%
df.head()      ## It represent the 1 st five row of the particular data.
# Out:
#   submission_date state tot_cases conf_cases prob_cases new_case pnew_case  \
# 0      01/14/2022    KS   621,273    470,516    150,757   19,414     6,964
# 1      01/02/2022    AS        11        NaN        NaN        0         0
# 2      02/04/2020    AR         0        NaN        NaN        0       NaN
# 3      12/06/2021    MP     1,104      1,104          0        0         0
# 4      05/09/2021    PW         0        NaN        NaN        0         0
#
#   tot_death conf_death prob_death new_death pnew_death  \
# 0     7,162        NaN        NaN        21          4
# 1         0        NaN        NaN         0          0
# 2         0        NaN        NaN         0        NaN
# 3         5          5          0         2          0
# 4         0        NaN        NaN         0          0
#
#                created_at consent_cases consent_deaths
# 0  01/15/2022 02:59:30 PM         Agree            NaN
# 1  01/03/2022 03:18:16 PM           NaN            NaN
# ...

# %%
df.info()      ##The information contains the number of columns, column labels, column data types, memory usage, range index,
               ##and the number of cells in each column (non-null values).
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50361 entries, 0 to 50360
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   submission_date  50361 non-null  object
#  1   state            50361 non-null  object
#  2   tot_cases        50361 non-null  object
#  3   conf_cases       27885 non-null  object
#  4   prob_cases       27813 non-null  object
#  5   new_case         50361 non-null  object
#  6   pnew_case        46659 non-null  object
#  7   tot_death        50361 non-null  object
#  8   conf_death       27448 non-null  object
#  9   prob_death       27448 non-null  object
#  10  new_death        50361 non-null  object
#  11  pnew_death       46691 non-null  object
#  12  created_at       50361 non-null  object
#  13  consent_cases    41966 non-null  object
#  14  consent_deaths   42810 non-null  object
# dtypes: object(15)
# memory usage: 5.8+ MB

# %%
df.describe()    ##describe function is used to get a descriptive statistics summary of a given dataframe.
                 ##This includes mean, count, std deviation, percentiles, and min-max values of all the features.
# Out:
#        submission_date  state tot_cases conf_cases prob_cases new_case  \
# count            50361  50361     50361      27885      27813    50361
# unique             860     60     37784      22898      16503     7568
# top         01/14/2022     AL         0          0          0        0
# freq                60    860      3971        766       6400     9929
#
#        pnew_case tot_death conf_death prob_death new_death pnew_death  \
# count      46659     50361      27448      27448     50361      46691
# unique      2964     16880      12621       3872       505        320
# top            0         0          0          0         0          0
# freq       21637      6426       2057       7185     18040      33153
#
#                     created_at consent_cases consent_deaths
# count                    50361         41966          42810
# unique                    1913             2              2
# top     03/26/2020 04:22:39 PM         Agree          Agree
# ...

# %%
df_CA =df[df['state'] =='CA']   # initialize a sub-dataframe for storing only the values for the california
df_CA
# Out:
#       submission_date state  tot_cases conf_cases prob_cases new_case  \
# 10539      12/12/2021    CA  5,133,238  4,867,604    265,634        0
# 10541      02/28/2022    CA  8,960,997  8,381,196    579,801   19,492
# 10564      09/15/2021    CA  4,574,136  4,380,566    193,570    7,760
# 10676      06/11/2021    CA  3,694,498  3,694,498          0    1,136
# 10683      06/08/2021    CA  3,691,660  3,691,660          0      792
# ...               ...   ...        ...        ...        ...      ...
# 34707      12/24/2021    CA  5,264,182  4,990,016    274,166   20,401
# 34719      01/28/2022    CA  8,213,786  7,706,395    507,391   76,729
# 34765      10/09/2020    CA    838,606    838,606          0    3,806
# 34778      08/29/2020    CA    693,839    693,839          0    4,981
# 34805      01/07/2022    CA  5,947,810  5,634,357    313,453  103,606
#
#       pnew_case tot_death conf_death prob_death new_death pnew_death  \
# ...

# %%
df_CA.shape
# Out:
# (839, 15)

# %%
tot_cases =np.array((df_CA['tot_cases']))  # creation an array with the total no. of the cases
days = np.linspace(0 ,len(tot_cases),len(tot_cases)) # array containing the n of the days from the first recordinh

# %%
tot_cases
# Out:
# array(['5,133,238', '8,960,997', '4,574,136', '3,694,498', '3,691,660',
#        '9,084,834', '739,527', '4,885,289', '4,653,610', '586,056',
#        '122,901', '9,105,181', '5,041,193', '5,084,927', '1,389,707',
#        '9,140,562', '26,182', '3,553,307', '12,026', '4,429,964',
#        '2,781,039', '538,416', '4,276,720', '3,484,963', '10,566',
#        '3,656,967', '23,253', '3,555,915', '9,115,022', '3,677,235', '6',
#        '3,661,675', '8,775,930', '944,576', '4,653,610', '7,570,538',
#        '3,465,726', '4,676,579', '247', '722,283', '5,844,204',
#        '4,826,113', '904,198', '4,554,525', '3,559,193', '5,264,182',
#        '5,204,695', '3,428,518', '760,013', '4,749,201', '1,286,557',
#        '514,901', '4,972,469', '1,854,456', '3,659,641', '9,155,320',
#        '8,867,026', '312,344', '3,294,447', '6', '165,416', '4,515,931',
#        '4,355,018', '485,502', '8,545,237', '3,085,040', '133',
#        '8,941,505', '4,466,363', '991,609', '3,688,893', '4,497,019',
# ...

# %%
len(days)
# Out:
# 839

# %%
d = {
    "days" : pd.Series(days,index= None),
    "tot_cases":pd.Series(tot_cases,index = None),
}

# %%
d
# Out:
# {'days': 0        0.000000
#  1        1.001193
#  2        2.002387
#  3        3.003580
#  4        4.004773
#            ...
#  834    834.995227
#  835    835.996420
#  836    836.997613
#  837    837.998807
#  838    839.000000
#  Length: 839, dtype: float64,
#  'tot_cases': 0      5,133,238
#  1      8,960,997
#  2      4,574,136
#  3      3,694,498
#  4      3,691,660
#           ...
#  834    5,264,182
#  835    8,213,786
#  836      838,606
#  837      693,839
#  838    5,947,810
#  Length: 839, dtype: object}

# %%
df2 = pd.DataFrame(d)   # coloumns=["tot_cases,"days]
df2
# Out:
#            days  tot_cases
# 0      0.000000  5,133,238
# 1      1.001193  8,960,997
# 2      2.002387  4,574,136
# 3      3.003580  3,694,498
# 4      4.004773  3,691,660
# ..          ...        ...
# 834  834.995227  5,264,182
# 835  835.996420  8,213,786
# 836  836.997613    838,606
# 837  837.998807    693,839
# 838  839.000000  5,947,810
#
# [839 rows x 2 columns]

# %%
df2= pd.DataFrame(d)

# %%
df2["tot_cases"]=df2['tot_cases'].str.replace(',','').astype(float)

# %%
df2["tot_cases"]
# Out:
# 0      5133238.0
# 1      8960997.0
# 2      4574136.0
# 3      3694498.0
# 4      3691660.0
#          ...
# 834    5264182.0
# 835    8213786.0
# 836     838606.0
# 837     693839.0
# 838    5947810.0
# Name: tot_cases, Length: 839, dtype: float64

# %%
df2["days"][:200]
# Out:
# 0        0.000000
# 1        1.001193
# 2        2.002387
# 3        3.003580
# 4        4.004773
#           ...
# 195    195.232697
# 196    196.233890
# 197    197.235084
# 198    198.236277
# 199    199.237470
# Name: days, Length: 200, dtype: float64

# %%
# defination of the fitting function
def exp_fit(x,a,b,c):
    y =a*np.exp(b*x)+c
    return y

# %%
#call the fitting function
fit = curve_fit (exp_fit, df2["days"] [:122] , df2["tot_cases"] [:122] ,p0 = [0.005,0.03,5])
fit_eq = fit[0][0]*np.exp(fit[0][1]*df2["days"][:122]) + fit[0][2]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# plotting #
fig = plt.figure()
ax=fig.subplots()
ax.scatter(df2["days"][:122],df2["tot_cases"][:122],color ='b',s = 30)
ax.plot(df2["days"][:122],fit_eq,color = 'r',alpha = 1)
ax.set_ylabel('total cases')
ax.set_xlabel('N° OF THE day')
plt.show()

# %% [markdown]
# ##  Applying An Random Exponential Distribution Fit To A Histogram

# %%
# applying an exponential fit to a histogram
data = np.random.exponential(5,size=10000)  # generating a random exponentialdistribution
hist = np.histogram(data,bins='auto')[0] # generating a histogram from exp.dis
x = np.arange(0,len(hist),1)# generating the array that contain the coordinator of the left ege of each bar

# %%
# decaying fit of the distribution 
def exp_fit(x,a,b):
    y = a*np.exp(-b*x)
    return y

x_fit = x + x[1]/2 #the point of the fit will be position at the center of the bin
fit_ = curve_fit(exp_fit,x_fit,hist)# calling the fit function
fit_eq = fit_[0][0]*np.exp(-fit_[0][1]*x_fit)# building the y array of the fit
# Out:
# C:\Users\Rutuja Mali\AppData\Local\Temp\ipykernel_8068\2572695926.py:3: RuntimeWarning: overflow encountered in exp
#   y = a*np.exp(-b*x)
# C:\Users\Rutuja Mali\AppData\Local\Temp\ipykernel_8068\2572695926.py:3: RuntimeWarning: overflow encountered in multiply
#   y = a*np.exp(-b*x)

# %%
plt.bar(x,hist,alpha=0.6,align='edge',width=1)
plt.ylabel('totalcases')
plt.xlabel('N° of days')
plt.show()

# %%
# plotting
plt.bar(x,hist,alpha=0.6,align='edge',width=1)
plt.plot(x_fit,fit_eq,color='red')
plt.show()

# %%
# plotting
plt.bar(x,hist,alpha=0.6,align='edge',width=1)
plt.plot(x_fit,fit_eq,color='blue')
plt.show()

# %% [markdown]
# #  Conclusion:

# %% [markdown]
# ####  1) In these project we learn the how to explore the data set with help of best curve fit.

# %% [markdown]
# #### 2) how to applying random exponential distribution fit to a histogram.
